# %% [markdown]
# <a href="https://colab.research.google.com/github/NiroNithy/Personal_Portfolio/blob/Research/PeopleXGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# %%
#LOAD THE DATA
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

df=pd.read_csv('/content/PeopleBank Dataset.csv',encoding='ISO-8859-1')
df
# Out:
#                                                content                   at  \
# 0    After the recent update, I can't use the app. ...  2025-01-25T06:58:49
# 1    Shows me a message after the latest update. "T...  2025-01-25T06:12:57
# 2    Not opening without finger print. My phone is ...  2025-01-25T03:05:31
# 3    I updated this app on 25 th January 2025. Afte...  2025-01-25T01:09:05
# 4    Every time Unable connect server what's this ð...  2025-01-23T12:39:13
# ..                                                 ...                  ...
# 915                                              Super  2022-01-18T06:42:34
# 916                            Register step 3 problem  2022-01-17T09:37:47
# 917                            Too much authentication  2022-01-14T23:48:56
# 918  Transaction confirmation pdf not received. So,...  2022-01-11T07:04:08
# 919  Really helpful, allow me to manage all the bil...  2022-01-08T16:16:34
#
#      appVersion
# 0    V 1.36.1.2
# 1    V 1.36.1.2
# 2    V 1.36.1.2
# 3    V 1.36.1.2
# 4    V 1.34.1.2
# ..          ...
# 915  V 1.24.1.2
# 916  V 1.24.1.2
# 917  V 1.24.1.2
# 918  V 1.24.1.2
# 919  V 1.24.1.2
#
# [920 rows x 3 columns]

# %%
# Download NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Preprocessing function
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    return ' '.join(word for word in words if word.isalnum() and word not in stop_words)

# %%
# Apply preprocessing to the content column
df['cleaned_content'] = df['content'].apply(preprocess_text)

# %%
df
# Out:
#                                                content                   at  \
# 0    After the recent update, I can't use the app. ...  2025-01-25T06:58:49
# 1    Shows me a message after the latest update. "T...  2025-01-25T06:12:57
# 2    Not opening without finger print. My phone is ...  2025-01-25T03:05:31
# 3    I updated this app on 25 th January 2025. Afte...  2025-01-25T01:09:05
# 4    Every time Unable connect server what's this ð...  2025-01-23T12:39:13
# ..                                                 ...                  ...
# 915                                              Super  2022-01-18T06:42:34
# 916                            Register step 3 problem  2022-01-17T09:37:47
# 917                            Too much authentication  2022-01-14T23:48:56
# 918  Transaction confirmation pdf not received. So,...  2022-01-11T07:04:08
# 919  Really helpful, allow me to manage all the bil...  2022-01-08T16:16:34
#
#      appVersion                                    cleaned_content
# 0    V 1.36.1.2  recent update ca use app keep showing device a...
# 1    V 1.36.1.2  shows message latest update device app signatu...
# 2    V 1.36.1.2  opening without finger print phone available f...
# 3    V 1.36.1.2  updated app 25 th january open app message app...
# 4    V 1.34.1.2                   every time unable connect server
# ..          ...                                                ...
# 915  V 1.24.1.2                                              super
# 916  V 1.24.1.2                            register step 3 problem
# 917  V 1.24.1.2                                much authentication
# 918  V 1.24.1.2  transaction confirmation pdf received prove so...
# 919  V 1.24.1.2  really helpful allow manage bill payments tran...
#
# [920 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Initialize VADER Sentiment Analyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sia = SentimentIntensityAnalyzer()

# %%
#Take Sentiment Score
def classify_sentiment(score):
  if score >= 0.05:
    return 'positive'
  elif score <= 0.05:
    return 'negative'
  else:
    return 'netural'

#new output column as sentiment score(value)
df['sentiment_score'] = df['content'].apply(lambda x:sia.polarity_scores(x)['compound'])
df['sentiment'] = df['sentiment_score'].apply(classify_sentiment)

# %%
df
# Out:
#                                                content                   at  \
# 0    After the recent update, I can't use the app. ...  2025-01-25T06:58:49
# 1    Shows me a message after the latest update. "T...  2025-01-25T06:12:57
# 2    Not opening without finger print. My phone is ...  2025-01-25T03:05:31
# 3    I updated this app on 25 th January 2025. Afte...  2025-01-25T01:09:05
# 4    Every time Unable connect server what's this ð...  2025-01-23T12:39:13
# ..                                                 ...                  ...
# 915                                              Super  2022-01-18T06:42:34
# 916                            Register step 3 problem  2022-01-17T09:37:47
# 917                            Too much authentication  2022-01-14T23:48:56
# 918  Transaction confirmation pdf not received. So,...  2022-01-11T07:04:08
# 919  Really helpful, allow me to manage all the bil...  2022-01-08T16:16:34
#
#      appVersion                                    cleaned_content  \
# 0    V 1.36.1.2  recent update ca use app keep showing device a...
# 1    V 1.36.1.2  shows message latest update device app signatu...
# 2    V 1.36.1.2  opening without finger print phone available f...
# 3    V 1.36.1.2  updated app 25 th january open app message app...
# 4    V 1.34.1.2                   every time unable connect server
# ..          ...                                                ...
# 915  V 1.24.1.2                                              super
# 916  V 1.24.1.2                            register step 3 problem
# 917  V 1.24.1.2                                much authentication
# 918  V 1.24.1.2  transaction confirmation pdf received prove so...
# 919  V 1.24.1.2  really helpful allow manage bill payments tran...
#
#      sentiment_score sentiment
# 0             0.3182  positive
# 1             0.0000  negative
# 2             0.0000  negative
# 3             0.3182  positive
# 4             0.0000  negative
# ..               ...       ...
# 915           0.5994  positive
# 916          -0.4019  negative
# 917           0.0000  negative
# 918           0.0000  negative
# 919           0.9088  positive
#
# [920 rows x 6 columns]

# %%
#Filter rows with negative sentiment
negative_reviews = df[df['sentiment'] == 'negative']

# %%
negative_reviews
# Out:
#                                                content                   at  \
# 1    Shows me a message after the latest update. "T...  2025-01-25T06:12:57
# 2    Not opening without finger print. My phone is ...  2025-01-25T03:05:31
# 4    Every time Unable connect server what's this ð...  2025-01-23T12:39:13
# 6     Always app is not working.It says server timeout  2025-01-21T05:26:13
# 8    Sometimes when using it, its functionality doe...  2025-01-13T08:15:39
# ..                                                 ...                  ...
# 911  After we transfer to money to other account,ca...  2022-01-25T08:25:56
# 912  I am using my mobile phone to connect. But eve...  2022-01-24T03:14:41
# 916                            Register step 3 problem  2022-01-17T09:37:47
# 917                            Too much authentication  2022-01-14T23:48:56
# 918  Transaction confirmation pdf not received. So,...  2022-01-11T07:04:08
#
#      appVersion                                    cleaned_content  \
# 1    V 1.36.1.2  shows message latest update device app signatu...
# 2    V 1.36.1.2  opening without finger print phone available f...
# 4    V 1.34.1.2                   every time unable connect server
# 6    V 1.34.1.2                     always app says server timeout
# 8    V 1.34.1.2  sometimes using functionality seem work unable...
# ..          ...                                                ...
# 911  V 1.24.1.2     transfer money account ca download responsible
# 912  V 1.24.1.2  using mobile phone connect everytime trying lo...
# 916  V 1.24.1.2                            register step 3 problem
# 917  V 1.24.1.2                                much authentication
# 918  V 1.24.1.2  transaction confirmation pdf received prove so...
#
#      sentiment_score sentiment
# 1             0.0000  negative
# 2             0.0000  negative
# 4             0.0000  negative
# 6             0.0000  negative
# 8             0.0000  negative
# ..               ...       ...
# 911          -0.2411  negative
# 912           0.0000  negative
# 916          -0.4019  negative
# 917           0.0000  negative
# 918           0.0000  negative
#
# [450 rows x 6 columns]

# %%
# Convert text to a TF-IDF representation
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_dtm = tfidf_vectorizer.fit_transform(negative_reviews['cleaned_content'])

# %%
# Apply LDA for topic modeling
lda = LatentDirichletAllocation(n_components=2, random_state=42)  # Assume 2 topics (UI, UX)
lda.fit(tfidf_dtm)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
# Extract keywords for each topic
def get_top_keywords(model, feature_names, n_top_words):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        topics[f"Topic {topic_idx + 1}"] = [feature_names[i] for i in topic.argsort()[-n_top_words:]]
    return topics

n_top_words = 20
feature_names = tfidf_vectorizer.get_feature_names_out()
topics = get_top_keywords(lda, feature_names, n_top_words)

# %%
print("Identified Topics with Keywords:")
for topic, keywords in topics.items():
   print(f"{topic}: {', '.join(keywords)}")
# Out:
# Identified Topics with Keywords:
# Topic 1: useless, need, screenshot, transaction, poor, banking, change, open, friendly, service, login, slow, bank, user, ca, time, password, bad, worst, app
# Topic 2: error, screen, wasting, payment, people, naic, time, mobile, usefull, properly, account, work, app, new, log, connect, server, unable, update, working

# %%
#Assign the most probable topic to each review
negative_reviews['topic'] = lda.transform(tfidf_dtm).argmax(axis=1)
# Out:
# <ipython-input-18-1c6ee9867e2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews['topic'] = lda.transform(tfidf_dtm).argmax(axis=1)

# %%
# Map topic numbers to labels
topic_labels = {0: 'UI', 1: 'UX'}
negative_reviews['classification'] = negative_reviews['topic'].map(topic_labels)
# Out:
# <ipython-input-19-6f27e2f65528>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews['classification'] = negative_reviews['topic'].map(topic_labels)

# %%
negative_reviews
# Out:
#                                                content                   at  \
# 1    Shows me a message after the latest update. "T...  2025-01-25T06:12:57
# 2    Not opening without finger print. My phone is ...  2025-01-25T03:05:31
# 4    Every time Unable connect server what's this ð...  2025-01-23T12:39:13
# 6     Always app is not working.It says server timeout  2025-01-21T05:26:13
# 8    Sometimes when using it, its functionality doe...  2025-01-13T08:15:39
# ..                                                 ...                  ...
# 911  After we transfer to money to other account,ca...  2022-01-25T08:25:56
# 912  I am using my mobile phone to connect. But eve...  2022-01-24T03:14:41
# 916                            Register step 3 problem  2022-01-17T09:37:47
# 917                            Too much authentication  2022-01-14T23:48:56
# 918  Transaction confirmation pdf not received. So,...  2022-01-11T07:04:08
#
#      appVersion                                    cleaned_content  \
# 1    V 1.36.1.2  shows message latest update device app signatu...
# 2    V 1.36.1.2  opening without finger print phone available f...
# 4    V 1.34.1.2                   every time unable connect server
# 6    V 1.34.1.2                     always app says server timeout
# 8    V 1.34.1.2  sometimes using functionality seem work unable...
# ..          ...                                                ...
# 911  V 1.24.1.2     transfer money account ca download responsible
# 912  V 1.24.1.2  using mobile phone connect everytime trying lo...
# 916  V 1.24.1.2                            register step 3 problem
# 917  V 1.24.1.2                                much authentication
# 918  V 1.24.1.2  transaction confirmation pdf received prove so...
#
#      sentiment_score sentiment  topic classification
# 1             0.0000  negative      1             UX
# 2             0.0000  negative      1             UX
# 4             0.0000  negative      1             UX
# 6             0.0000  negative      0             UI
# 8             0.0000  negative      1             UX
# ..               ...       ...    ...            ...
# 911          -0.2411  negative      0             UI
# 912           0.0000  negative      1             UX
# 916          -0.4019  negative      0             UI
# 917           0.0000  negative      1             UX
# 918           0.0000  negative      0             UI
#
# [450 rows x 8 columns]

# %%
# Split the data into training and testing sets
X = tfidf_dtm.toarray()
Y = negative_reviews['classification'].apply(lambda x: 0 if x == 'UI' else 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Ensure X and Y are NumPy arrays
X = np.array(X)  # Convert X to a NumPy array if it isn't already
Y = np.array(Y)  # Convert Y to a NumPy array if it isn't already

# %%
# Initialize XGBoost
xgb = XGBClassifier(eval_metric='logloss', random_state=42)

# %%
# Train the XGBoost model
xgb.fit(X_train, Y_train)

# Predict on the test set
Y_pred = xgb.predict(X_test)

# Calculate Accuracy
accuracy = accuracy_score(Y_test, Y_pred)

# Calculate MSE (Mean Squared Error)
mse = mean_squared_error(Y_test, Y_pred)

# Print results
print(f"XGBoost Accuracy: {accuracy:.2f}")
print(f"XGBoost Mean Squared Error (MSE): {mse:.2f}")
# Out:
# XGBoost Accuracy: 0.76
# XGBoost Mean Squared Error (MSE): 0.24

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# Classification report
print(classification_report(Y_test, Y_pred, target_names=['UI', 'UX']))

# Or individual scores
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
#               precision    recall  f1-score   support
#
#           UI       0.80      0.85      0.83        62
#           UX       0.62      0.54      0.58        28
#
#     accuracy                           0.76        90
#    macro avg       0.71      0.70      0.70        90
# weighted avg       0.75      0.76      0.75        90
#
# Precision: 0.62
# Recall: 0.54
# F1 Score: 0.58

# %%
import collections

# Count labels
print("Train set distribution:", collections.Counter(Y_train))
print("Test set distribution:", collections.Counter(Y_test))
# Out:
# Train set distribution: Counter({0: 251, 1: 109})
# Test set distribution: Counter({0: 62, 1: 28})

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Get prediction probabilities (before thresholding)
Y_probs = xgb.predict(X_test).flatten()

# Compute Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(Y_test, Y_probs)
auprc = average_precision_score(Y_test, Y_probs)

# Plot the Precision-Recall curve
plt.figure(figsize=(8, 5))
plt.plot(recall, precision)
plt.title(f'XGBoost Precision-Recall Curve (AUPRC = {auprc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

# Prepare the data
X = tfidf_dtm.toarray()
Y = negative_reviews['classification'].apply(lambda x: 0 if x == 'UI' else 1)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Initialize XGBoost with eval metric and early stopping
xgb = XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=42)

# Train the model with evaluation set
eval_set = [(X_train, Y_train), (X_test, Y_test)]
xgb.fit(X_train, Y_train, eval_set=eval_set, verbose=False)

# Retrieve training results
results = xgb.evals_result()

# Extract accuracies
epochs = len(results['validation_0']['logloss'])
x_axis = range(0, epochs)

# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(x_axis, results['validation_0']['logloss'], label='Training Log Loss', color='blue')
plt.plot(x_axis, results['validation_1']['logloss'], label='Validation Log Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('XGBoost Training and Validation Log Loss')
plt.legend()
plt.grid(True)
plt.show()

# Final evaluation
Y_pred = xgb.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

print(f"XGBoost Accuracy: {accuracy:.2f}")
print(f"XGBoost Mean Squared Error (MSE): {mse:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:03:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.81
# XGBoost Mean Squared Error (MSE): 0.19

# %%
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

# Prepare the data
X = tfidf_dtm.toarray()
Y = negative_reviews['classification'].apply(lambda x: 0 if x == 'UI' else 1)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Initialize XGBoost with eval metric and early stopping
xgb = XGBClassifier(eval_metric='logloss', use_label_encoder=False, random_state=42)

# Train the model with evaluation set
eval_set = [(X_train, Y_train), (X_test, Y_test)]
xgb.fit(X_train, Y_train, eval_set=eval_set, verbose=False)

# Retrieve training results
results = xgb.evals_result()

# Extract logloss values from eval results (logloss corresponds to the loss during training)
train_logloss = results['validation_0']['logloss']
val_logloss = results['validation_1']['logloss']

# Convert logloss to accuracy (accuracy = 1 - logloss)
train_accuracy = [1 - loss for loss in train_logloss]
val_accuracy = [1 - loss for loss in val_logloss]

# Determine the number of epochs
epochs = len(train_accuracy)
x_axis = range(0, epochs)

# Plot the training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(x_axis, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(x_axis, val_accuracy, label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('XGBoost Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Final evaluation
Y_pred = xgb.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

print(f"XGBoost Accuracy: {accuracy:.2f}")
print(f"XGBoost Mean Squared Error (MSE): {mse:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:07:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.81
# XGBoost Mean Squared Error (MSE): 0.19
