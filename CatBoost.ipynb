# %% [markdown]
# <a href="https://colab.research.google.com/github/NiroNithy/Personal_Portfolio/blob/Research/CatBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
#LOAD THE DATA
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

df=pd.read_csv('/content/BOC_Dataset.csv',encoding='ISO-8859-1')
df
# Out:
#                                                content                   at  \
# 0                      It's time to do the Revamp ð´  2024-12-01T17:38:26
# 1                         Bad UX experience and Bad UI  2024-11-30T09:53:50
# 2                            The worst app I ever used  2024-11-30T03:47:02
# 3    This app needs a revision soon. All other comp...  2024-11-29T03:49:26
# 4    Worst banking app ever. Not user friendly at a...  2024-11-25T23:17:11
# ..                                                 ...                  ...
# 706                    Not perfect but it does the job  2023-10-02T05:29:54
# 707    I think 2000 years OLD app develepors workinga.  2023-10-02T02:40:43
# 708  Great app.. easy to access all services. Pleas...  2023-09-30T19:58:34
# 709                                           ð¥ð  2023-09-29T03:17:55
# 710  Gobba gobba goothama app eka, transaction ekak...  2023-09-27T13:25:39
#
#     appVersion
# 0       1.2.27
# 1       1.2.27
# 2       1.2.27
# 3       1.2.27
# 4       1.2.27
# ..         ...
# 706     1.2.27
# 707     1.2.27
# 708     1.2.27
# 709     1.2.27
# 710     1.2.27
#
# [711 rows x 3 columns]

# %%
# Download NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Preprocessing function
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    return ' '.join(word for word in words if word.isalnum() and word not in stop_words)

# %%
# Apply preprocessing to the content column
df['cleaned_content'] = df['content'].apply(preprocess_text)

# %%
df
# Out:
#                                                content                   at  \
# 0                      It's time to do the Revamp ð´  2024-12-01T17:38:26
# 1                         Bad UX experience and Bad UI  2024-11-30T09:53:50
# 2                            The worst app I ever used  2024-11-30T03:47:02
# 3    This app needs a revision soon. All other comp...  2024-11-29T03:49:26
# 4    Worst banking app ever. Not user friendly at a...  2024-11-25T23:17:11
# ..                                                 ...                  ...
# 706                    Not perfect but it does the job  2023-10-02T05:29:54
# 707    I think 2000 years OLD app develepors workinga.  2023-10-02T02:40:43
# 708  Great app.. easy to access all services. Pleas...  2023-09-30T19:58:34
# 709                                           ð¥ð  2023-09-29T03:17:55
# 710  Gobba gobba goothama app eka, transaction ekak...  2023-09-27T13:25:39
#
#     appVersion                                    cleaned_content
# 0       1.2.27                                        time revamp
# 1       1.2.27                           bad ux experience bad ui
# 2       1.2.27                                worst app ever used
# 3       1.2.27  app needs revision soon competitors adopted bi...
# 4       1.2.27  worst banking app ever user friendly leading b...
# ..         ...                                                ...
# 706     1.2.27                                        perfect job
# 707     1.2.27       think 2000 years old app develepors workinga
# 708     1.2.27  great app easy access services please change b...
# 709     1.2.27
# 710     1.2.27  gobba gobba goothama app eka transaction ekak ...
#
# [711 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Initialize VADER Sentiment Analyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

# %%
#Take Sentiment Score
def classify_sentiment(score):
  if score >= 0.05:
    return 'positive'
  elif score <= 0.05:
    return 'negative'
  else:
    return 'netural'

#new output column as sentiment score(value)
df['sentiment_score'] = df['content'].apply(lambda x:sia.polarity_scores(x)['compound'])
df['sentiment'] = df['sentiment_score'].apply(classify_sentiment)

# %%
df
# Out:
#                                                content                   at  \
# 0                      It's time to do the Revamp ð´  2024-12-01T17:38:26
# 1                         Bad UX experience and Bad UI  2024-11-30T09:53:50
# 2                            The worst app I ever used  2024-11-30T03:47:02
# 3    This app needs a revision soon. All other comp...  2024-11-29T03:49:26
# 4    Worst banking app ever. Not user friendly at a...  2024-11-25T23:17:11
# ..                                                 ...                  ...
# 706                    Not perfect but it does the job  2023-10-02T05:29:54
# 707    I think 2000 years OLD app develepors workinga.  2023-10-02T02:40:43
# 708  Great app.. easy to access all services. Pleas...  2023-09-30T19:58:34
# 709                                           ð¥ð  2023-09-29T03:17:55
# 710  Gobba gobba goothama app eka, transaction ekak...  2023-09-27T13:25:39
#
#     appVersion                                    cleaned_content  \
# 0       1.2.27                                        time revamp
# 1       1.2.27                           bad ux experience bad ui
# 2       1.2.27                                worst app ever used
# 3       1.2.27  app needs revision soon competitors adopted bi...
# 4       1.2.27  worst banking app ever user friendly leading b...
# ..         ...                                                ...
# 706     1.2.27                                        perfect job
# 707     1.2.27       think 2000 years old app develepors workinga
# 708     1.2.27  great app easy access services please change b...
# 709     1.2.27
# 710     1.2.27  gobba gobba goothama app eka transaction ekak ...
#
#      sentiment_score sentiment
# 0             0.0000  negative
# 1            -0.7906  negative
# 2            -0.6249  negative
# 3             0.0000  negative
# 4            -0.7527  negative
# ..               ...       ...
# 706          -0.2498  negative
# 707           0.0000  negative
# 708           0.9260  positive
# 709           0.0000  negative
# 710          -0.2960  negative
#
# [711 rows x 6 columns]

# %%
#Filter rows with negative sentiment
negative_reviews = df[df['sentiment'] == 'negative']

# %%
negative_reviews
# Out:
#                                                content                   at  \
# 0                      It's time to do the Revamp ð´  2024-12-01T17:38:26
# 1                         Bad UX experience and Bad UI  2024-11-30T09:53:50
# 2                            The worst app I ever used  2024-11-30T03:47:02
# 3    This app needs a revision soon. All other comp...  2024-11-29T03:49:26
# 4    Worst banking app ever. Not user friendly at a...  2024-11-25T23:17:11
# ..                                                 ...                  ...
# 705                     Worst banking app in Sri Lanka  2023-10-02T11:23:30
# 706                    Not perfect but it does the job  2023-10-02T05:29:54
# 707    I think 2000 years OLD app develepors workinga.  2023-10-02T02:40:43
# 709                                           ð¥ð  2023-09-29T03:17:55
# 710  Gobba gobba goothama app eka, transaction ekak...  2023-09-27T13:25:39
#
#     appVersion                                    cleaned_content  \
# 0       1.2.27                                        time revamp
# 1       1.2.27                           bad ux experience bad ui
# 2       1.2.27                                worst app ever used
# 3       1.2.27  app needs revision soon competitors adopted bi...
# 4       1.2.27  worst banking app ever user friendly leading b...
# ..         ...                                                ...
# 705     1.2.27                        worst banking app sri lanka
# 706     1.2.27                                        perfect job
# 707     1.2.27       think 2000 years old app develepors workinga
# 709     1.2.27
# 710     1.2.27  gobba gobba goothama app eka transaction ekak ...
#
#      sentiment_score sentiment
# 0             0.0000  negative
# 1            -0.7906  negative
# 2            -0.6249  negative
# 3             0.0000  negative
# 4            -0.7527  negative
# ..               ...       ...
# 705          -0.6249  negative
# 706          -0.2498  negative
# 707           0.0000  negative
# 709           0.0000  negative
# 710          -0.2960  negative
#
# [547 rows x 6 columns]

# %%
# Convert text to a TF-IDF representation
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_dtm = tfidf_vectorizer.fit_transform(negative_reviews['cleaned_content'])

# %%
# Apply LDA for topic modeling
lda = LatentDirichletAllocation(n_components=2, random_state=42)  # Assume 2 topics (UI, UX)
lda.fit(tfidf_dtm)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
# Extract keywords for each topic
def get_top_keywords(model, feature_names, n_top_words):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        topics[f"Topic {topic_idx + 1}"] = [feature_names[i] for i in topic.argsort()[-n_top_words:]]
    return topics

n_top_words = 20
feature_names = tfidf_vectorizer.get_feature_names_out()
topics = get_top_keywords(lda, feature_names, n_top_words)

# %%
print("Identified Topics with Keywords:")
for topic, keywords in topics.items():
   print(f"{topic}: {', '.join(keywords)}")
# Out:
# Identified Topics with Keywords:
# Topic 1: mobile, times, loading, user, lanka, sri, open, useless, service, boc, login, log, ca, work, connect, bank, server, time, app, slow
# Topic 2: horrible, transfer, update, seen, access, need, really, error, properly, use, online, experience, application, poor, bad, used, working, banking, worst, app

# %%
#Assign the most probable topic to each review
negative_reviews['topic'] = lda.transform(tfidf_dtm).argmax(axis=1)
# Out:
# <ipython-input-19-1c6ee9867e2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews['topic'] = lda.transform(tfidf_dtm).argmax(axis=1)

# %%
# Map topic numbers to labels
topic_labels = {0: 'UI', 1: 'UX'}
negative_reviews['classification'] = negative_reviews['topic'].map(topic_labels)
# Out:
# <ipython-input-20-6f27e2f65528>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews['classification'] = negative_reviews['topic'].map(topic_labels)

# %%
negative_reviews
# Out:
#                                                content                   at  \
# 0                      It's time to do the Revamp ð´  2024-12-01T17:38:26
# 1                         Bad UX experience and Bad UI  2024-11-30T09:53:50
# 2                            The worst app I ever used  2024-11-30T03:47:02
# 3    This app needs a revision soon. All other comp...  2024-11-29T03:49:26
# 4    Worst banking app ever. Not user friendly at a...  2024-11-25T23:17:11
# ..                                                 ...                  ...
# 705                     Worst banking app in Sri Lanka  2023-10-02T11:23:30
# 706                    Not perfect but it does the job  2023-10-02T05:29:54
# 707    I think 2000 years OLD app develepors workinga.  2023-10-02T02:40:43
# 709                                           ð¥ð  2023-09-29T03:17:55
# 710  Gobba gobba goothama app eka, transaction ekak...  2023-09-27T13:25:39
#
#     appVersion                                    cleaned_content  \
# 0       1.2.27                                        time revamp
# 1       1.2.27                           bad ux experience bad ui
# 2       1.2.27                                worst app ever used
# 3       1.2.27  app needs revision soon competitors adopted bi...
# 4       1.2.27  worst banking app ever user friendly leading b...
# ..         ...                                                ...
# 705     1.2.27                        worst banking app sri lanka
# 706     1.2.27                                        perfect job
# 707     1.2.27       think 2000 years old app develepors workinga
# 709     1.2.27
# 710     1.2.27  gobba gobba goothama app eka transaction ekak ...
#
#      sentiment_score sentiment  topic classification
# 0             0.0000  negative      0             UI
# 1            -0.7906  negative      1             UX
# 2            -0.6249  negative      1             UX
# 3             0.0000  negative      1             UX
# 4            -0.7527  negative      0             UI
# ..               ...       ...    ...            ...
# 705          -0.6249  negative      0             UI
# 706          -0.2498  negative      0             UI
# 707           0.0000  negative      1             UX
# 709           0.0000  negative      0             UI
# 710          -0.2960  negative      0             UI
#
# [547 rows x 8 columns]

# %%
# Split the data into training and testing sets
X = tfidf_dtm.toarray()
Y = negative_reviews['classification'].apply(lambda x: 0 if x == 'UI' else 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Ensure X and Y are NumPy arrays
X = np.array(X)  # Convert X to a NumPy array if it isn't already
Y = np.array(Y)  # Convert Y to a NumPy array if it isn't already

# %%
# !pip install numpy==1.23.5
# !pip install catboost==1.2
# Out:
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)
# Requirement already satisfied: catboost==1.2 in /usr/local/lib/python3.11/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (3.10.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (1.14.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost==1.2) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost==1.2) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost==1.2) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost==1.2) (9.1.2)

# %%
from catboost import CatBoostClassifier

# %%
# Initialize CatBoost
catboost = CatBoostClassifier(verbose=0, random_state=42)

# %%
# Train CatBoost on training data
catboost.fit(X_train, Y_train)

# Predict on test data
Y_pred = catboost.predict(X_test)

# Calculate Accuracy
accuracy = accuracy_score(Y_test, Y_pred)

# Calculate MSE (Mean Squared Error)
mse = mean_squared_error(Y_test, Y_pred)

# Print results
print(f"CatBoost Accuracy: {accuracy:.2f}")
print(f"CatBoost Mean Squared Error (MSE): {mse:.2f}")
# Out:
# CatBoost Accuracy: 0.79
# CatBoost Mean Squared Error (MSE): 0.21

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# Classification report
print(classification_report(Y_test, Y_pred, target_names=['UI', 'UX']))

# Or individual scores
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
#               precision    recall  f1-score   support
#
#           UI       0.75      0.93      0.83        61
#           UX       0.88      0.61      0.72        49
#
#     accuracy                           0.79       110
#    macro avg       0.82      0.77      0.78       110
# weighted avg       0.81      0.79      0.78       110
#
# Precision: 0.88
# Recall: 0.61
# F1 Score: 0.72

# %%
import collections

# Count labels
print("Train set distribution:", collections.Counter(Y_train))
print("Test set distribution:", collections.Counter(Y_test))
# Out:
# Train set distribution: Counter({0: 244, 1: 193})
# Test set distribution: Counter({0: 61, 1: 49})

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Get prediction probabilities (before thresholding)
Y_probs = catboost.predict(X_test).flatten()

# Compute Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(Y_test, Y_probs)
auprc = average_precision_score(Y_test, Y_probs)

# Plot the Precision-Recall curve
plt.figure(figsize=(8, 5))
plt.plot(recall, precision)
plt.title(f'CatBoost Precision-Recall Curve (AUPRC = {auprc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import accuracy_score, mean_squared_error

# Create Pool objects for training and validation
train_pool = Pool(X_train, Y_train)
eval_pool = Pool(X_test, Y_test)

# Initialize CatBoost
catboost = CatBoostClassifier(
    verbose=0,
    random_state=42,
    eval_metric='Accuracy',
    use_best_model=False
)

# Train with evaluation sets
catboost.fit(train_pool, eval_set=eval_pool, verbose=0)

# Get training and validation metrics
evals_result = catboost.get_evals_result()
train_acc = evals_result['learn']['Accuracy']
val_acc = evals_result['validation']['Accuracy']
epochs = range(1, len(train_acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_acc, label='Training Accuracy', color='blue')
plt.plot(epochs, val_acc, label='Validation Accuracy', color='red')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.title('CatBoost Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Predict on test data
Y_pred = catboost.predict(X_test)

# Calculate final metrics
accuracy = accuracy_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

# Print results
print(f"CatBoost Accuracy: {accuracy:.2f}")
print(f"CatBoost Mean Squared Error (MSE): {mse:.2f}")
# Out:
# CatBoost Accuracy: 0.79
# CatBoost Mean Squared Error (MSE): 0.21
