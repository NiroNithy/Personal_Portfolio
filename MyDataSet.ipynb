# %% [markdown]
# <a href="https://colab.research.google.com/github/NiroNithy/Personal_Portfolio/blob/Research/MyDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper #Scraping Reviews
# !pip install -q transformers #Sentiment
# !pip install -q plotly-express #Data Visualization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00

# %%
# !pip install PyYAML

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all
import plotly_express as px

# %%
boc_project = reviews_all('com.ofss.fcdb.mobile.android.phone.boc.launcher', sleep_milliseconds=0, lang='en', sort = Sort.NEWEST)

# %%
#boc_project

# %%
df = pd.json_normalize(boc_project)

# %%
df.head()
# Out:
#                                reviewId       userName  \
# 0  e6a8950b-4d25-45e6-9790-6c1d90a4830b  A Google user
# 1  ae2f4b63-7272-449f-bf1d-9eac04345f96  A Google user
# 2  06645131-ad13-465b-ac4a-b508242fd41d  A Google user
# 3  095d7379-61b2-4aef-99dd-caca2198ac61  A Google user
# 4  04e010dd-dcd4-4a33-9a8a-846b855db453  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                       It's time to do the Revamp 😴      1              0
# 1  Their servers are always down at night. What a...      1              0
# 2                       Bad UX experience and Bad UI      1              0
# ...

# %%
columns_to_drop = ["reviewId", "userName", "userImage", "score", "thumbsUpCount", "reviewCreatedVersion", "replyContent","repliedAt"]
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#                                              content                  at  \
# 0                       It's time to do the Revamp 😴 2024-12-01 17:38:26
# 1  Their servers are always down at night. What a... 2024-12-01 10:43:37
# 2                       Bad UX experience and Bad UI 2024-11-30 09:53:50
# 3                          The worst app I ever used 2024-11-30 03:47:02
# 4  This app needs a revision soon. All other comp... 2024-11-29 03:49:26
#
#   appVersion
# 0     1.2.27
# 1       None
# 2     1.2.27
# 3     1.2.27
# 4     1.2.27

# %%
filtered_df = df[df["appVersion"] == "1.2.27"]

# %%
filtered_df.head()
# Out:
#                                              content                  at  \
# 0                       It's time to do the Revamp 😴 2024-12-01 17:38:26
# 2                       Bad UX experience and Bad UI 2024-11-30 09:53:50
# 3                          The worst app I ever used 2024-11-30 03:47:02
# 4  This app needs a revision soon. All other comp... 2024-11-29 03:49:26
# 8  Worst banking app ever. Not user friendly at a... 2024-11-25 23:17:11
#
#   appVersion
# 0     1.2.27
# 2     1.2.27
# 3     1.2.27
# 4     1.2.27
# 8     1.2.27

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=filtered_df)
# Out:
# https://docs.google.com/spreadsheets/d/18rYPwCItbp8nETC4AbG5c2D9RvsoQ2DUVhAKq7ooq9o#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/18rYPwCItbp8nETC4AbG5c2D9RvsoQ2DUVhAKq7ooq9o#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1aElgLL5UyUX5ZBt3w6-xpZNcDXqcbDhUGXKemfSr0Mc#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1aElgLL5UyUX5ZBt3w6-xpZNcDXqcbDhUGXKemfSr0Mc#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4378a91fe933> in <cell line: 2>()
#       1 columns_to_drop = ["reviewId", "userName", "userImage", "score", "thumbsUpCount", "reviewCreatedVersion", "replyContent","repliedAt"]
# ----> 2 df = df.drop(columns=columns_to_drop)
#
# NameError: name 'df' is not defined
